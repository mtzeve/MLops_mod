# %%
import requests
from datetime import datetime, timedelta
from dotenv import load_dotenv
import os

load_dotenv()

def fetch_articles(api_key, start_date, end_date):
    url = "https://api.marketaux.com/v1/news/all?symbols=TSLA&filter_entities=true&language=en&api_token=iy6rRX4oxFrouZocXr8JNpOzaxZLk3UvMfoMGxYs"
    headers = {"x-api-key": api_key}
    params = {
        "tickers": "TSLA",
        "filter_entities": "true",
        "language": "en",
        "from": start_date.strftime('%Y-%m-%d'),
        "to": end_date.strftime('%Y-%m-%d'),
        "page": 1
    }
    articles = []

    while True:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['data']
            articles.extend(data)
            if len(data) < 3:  # Assuming 3 articles per page is the limit
                break
            params['page'] += 1  # Increment to fetch the next page
        else:
            print(f"Failed to fetch data: {response.text}")
            break
        if params['page'] > 100:  # Prevent exceeding the daily request limit
            break

    return articles

# %%
def fetch_data_over_time(api_key, start_year):
    current_date = datetime.now()
    start_date = datetime(start_year, 1, 1)

    all_articles = []

    while start_date < current_date:
        end_date = start_date + timedelta(days=30)  # Fetch month by month
        if end_date > current_date:
            end_date = current_date

        print(f"Fetching from {start_date.date()} to {end_date.date()}")
        articles = fetch_articles(api_key, start_date, end_date)
        all_articles.extend(articles)

        start_date += timedelta(days=31)  # Move to the next month

    return all_articles

# %%
api_key = os.environ.get('news_api')
all_articles = fetch_data_over_time(api_key, 2017)
print(f"Total articles fetched: {len(all_articles)}")
# Out:
# Fetching from 2017-01-01 to 2017-01-31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> api_key = os.environ.get('news_api')
# ----> <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> all_articles = fetch_data_over_time(api_key, 2017)
#       <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> print(f"Total articles fetched: {len(all_articles)}")
#
# /Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     end_date = current_date
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> print(f"Fetching from {start_date.date()} to {end_date.date()}")
# ---> <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> articles = fetch_articles(api_key, start_date, end_date)
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> all_articles.extend(articles)
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a> start_date += timedelta(days=31)  # Move to the next month
#
# /Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> articles = []
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a> while True:
# ---> <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a>     response = requests.get(url, headers=headers, params=params)
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a>     if response.status_code == 200:
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a>         data = response.json()['data']
#
# File /Applications/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Applications/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Applications/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File /Applications/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File /Applications/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File /Applications/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /Applications/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /Applications/anaconda3/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /Applications/anaconda3/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File /Applications/anaconda3/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
all_articles
# Out:
# [{'uuid': 'f21ee777-8ceb-4352-8ead-088f094078a6',
#   'title': "S&P's Risk-On Momentum Gets Added Boost From Rebounding Profits",
#   'description': 'With the quarterly reporting season roughly half over, US corporate earnings have largely lived up to Wall Street’s optimistic expectations even as…',
#   'keywords': '',
#   'snippet': "This advertisement has not loaded yet, but your article continues below.\n\nS&P's Risk-On Momentum Gets Added Boost From Rebounding Profits With the quarterly rep...",
#   'url': 'https://financialpost.com/pmn/business-pmn/sps-risk-on-momentum-gets-added-boost-from-rebounding-profits',
#   'image_url': 'https://smartcdn.gprod.postmedia.digital/financialpost/wp-content/uploads/2024/04/improving-cpi-ppi-spread-supports-sps-margin-outlook-though.jpg',
#   'language': 'en',
#   'published_at': '2024-04-27T12:50:04.000000Z',
#   'source': 'financialpost.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 8.735703,
#     'sentiment_score': 0.3506,
#     'highlights': [{'highlight': 'Of the four Magnificent Seven firms that have reported — <em>Tesla</em> <em>Inc</em>., Meta, Microsoft and Alphabet — three have posted next-day moves that surpassed what options implied.\n\nAdvertisement 4 Story continues below This advertisement has not loaded yet, but your article continues below.',
#       'sentiment': 0.3506,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': '91bb4b80-a1db-465e-ab05-10978878a910',
#   'title': 'The "Magnificent Seven" Day of Reckoning Has Arrived: Three Moves to Make Now',
#   'description': 'The Nasdaq Composite just posted its worst week in 18 months.',
#   'keywords': '',
#   'snippet': "The Nasdaq Composite just posted its worst week in 18 months.\n\nApril 19 featured one of the most drastic tech-led sell-offs we've seen in a while, with Nvidia (...",
#   'url': 'https://www.fool.com/investing/2024/04/27/the-magnificent-seven-day-of-reckoning-has-arrived/',
#   'image_url': 'https://g.foolcdn.com/editorial/images/773665/gettyimages-1369513230-1201x782-76865a4-1.jpg',
#   'language': 'en',
#   'published_at': '2024-04-27T12:10:00.000000Z',
#   'source': 'finance.yahoo.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 10.255535,
#     'sentiment_score': 0.6808,
#     'highlights': [{'highlight': 'The Magnificent Seven is a term coined by Bank of America analyst Michael Hartnett and includes Microsoft, Apple, Nvidia, Amazon, Alphabet, Meta Platforms, and <em>Tesla</em>.\n\nHere are three moves you can make to brace for a prolonged market sell-off.\n\n1.',
#       'sentiment': 0.6808,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': '88ceedc6-4582-4c58-9ee6-7aea4b6e1953',
#   'title': 'Wall Street Breakfast: What Moved Markets',
#   'description': "The U.S. stocks rebounded this week amid positive earnings reports from Tesla, Microsoft, and Alphabet. Read more about last week's major events on Wall Street.",
#   'keywords': '',
#   'snippet': 'What a difference a week can make! After posting its worst weekly performance in over a year last Friday, the S&P 500 (SP500) rebounded this week to score its b...',
#   'url': 'https://seekingalpha.com/article/4686982-wall-street-breakfast-what-moved-markets',
#   'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1196426114/image_1196426114.jpg?io=getty-c-w1536',
#   'language': 'en',
#   'published_at': '2024-04-27T10:39:22.000000Z',
#   'source': 'seekingalpha.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 13.031082,
#     'sentiment_score': 0.279575,
#     'highlights': [{'highlight': 'The rise was primarily driven by a surge in technology stocks and other growth sectors, anchored by favorably received quarterly reports from <em>Tesla</em> (TSLA), Microsoft (MSFT), and Alphabet (GOOG) (GOOGL).',
#       'sentiment': 0.6369,
#       'highlighted_in': 'main_text'},
#      {'highlight': "Microsoft rose 4.4% AH on Thursday as AI adoption across its cloud services boosted its Q3 results. (100 comments)\n\n\n\n<em>Tesla</em> (TSLA) shot up 13% to $163.96/share AH on Tuesday, despite a sharp drop in Q1 earnings, deliveries, and margins, as investors latched on to the automaker's commitment to launch more affordable models that can be produced on existing",
#       'sentiment': 0.6622,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'CEO Elon Musk also talked up the latest Full Self-Driving software release, adding that <em>Tesla</em> is in talks with at least one major automaker about licensing FSD. SA analyst Steven Fiorillo said the market gave <em>Tesla</em> credit for its vision and product roadmap despite its weak quarter.',
#       'sentiment': 0.6318,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'But Investing Group Leader Jonathan Weber warned that <em>Tesla</em> has considerable operational problems while still trading at a premium valuation. (403 comments)\n\nPresident Biden signed a bill Wednesday that will force a U.S. ban on social media app TikTok unless it is divested from its Chinese parent, ByteDance (BDNCE), within about a year.',
#       'sentiment': -0.8126,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': '06141a58-09c6-45a9-831b-0e41c471de49',
#   'title': '1 "Magnificent Seven" Stock With 1,234% Upside, According to Cathie Wood',
#   'description': 'Tesla is the worst-performing stock in the "Magnificent Seven" this year, but Cathie Wood believes the long-term story is still intact.',
#   'keywords': '',
#   'snippet': 'Tesla is the worst-performing stock in the "Magnificent Seven" this year, but Cathie Wood believes the long-term story is still intact.\n\nLast year, a group of t...',
#   'url': 'https://www.fool.com/investing/2024/04/27/1-magnificent-seven-stock-1234-upside-cathie-wood/',
#   'image_url': 'https://g.foolcdn.com/editorial/images/774335/a-black-tesla-car-driving-on-an-open-road-in-the-snow.jpg',
#   'language': 'en',
#   'published_at': '2024-04-27T10:16:00.000000Z',
#   'source': 'finance.yahoo.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 14.17915,
#     'sentiment_score': -0.00014,
#     'highlights': [{'highlight': "The group includes:\n\nNvidia Meta Platforms Apple Microsoft Alphabet Amazon <em>Tesla</em> TSLA -1.11% )\n\nHowever, some of those stocks aren't looking so magnificent in 2024. <em>Tesla</em> is the worst performer of the bunch, and up until last week, it was sitting on a year-to-date loss of more than 40%.",
#       'sentiment': -0.6908,
#       'highlighted_in': 'main_text'},
#      {'highlight': "If Wood and her team at Ark are correct, investors who buy <em>Tesla</em> stock today could earn a whopping 1,234% gain. However, there are some glaring caveats.\n\n<em>Tesla</em> is facing a very difficult year\n\nOver the last few years, Elon Musk has reiterated Tesla's goal to grow its EV deliveries by 50% annually for the foreseeable future.",
#       'sentiment': 0.1621,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'For some perspective, <em>Tesla</em> slashed prices by over 25% throughout the year to spur demand, as consumers grappled with cost-of-living pressures.\n\n2024 could be even more challenging.',
#       'sentiment': -0.4284,
#       'highlighted_in': 'main_text'},
#      {'highlight': "There was a time when <em>Tesla</em> couldn't keep up with demand, but after building up to a production capacity of more than 2.3 million annual units, it appears consumers are shying away from EVs altogether.",
#       'sentiment': -0.3818,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'To stave off this threat, <em>Tesla</em> has revealed plans to start production on an affordable EV as soon as this year, and it could be priced as low as $25,000.',
#       'sentiment': -0.2732,
#       'highlighted_in': 'main_text'},
#      {'highlight': "It recently launched version 12 of its full self-driving (FSD) software, which allows <em>Tesla</em> vehicles to operate autonomously -- although it's still in beta mode, so human supervision is required.",
#       'sentiment': 0.128,
#       'highlighted_in': 'main_text'},
#      {'highlight': "The company intends to reveal a fully autonomous robotaxi called the Cybercab in August, and this long-awaited platform forms the basis of Cathie Wood's $2,000 price target for <em>Tesla</em> stock.",
#       'sentiment': 0,
#       'highlighted_in': 'main_text'},
#      {'highlight': "Musk plans to build an entire ride-hailing network at <em>Tesla</em> similar to Uber, except the Cybercab could operate around the clock, creating a new revenue stream for <em>Tesla</em> with very high profit margins.\n\nExisting <em>Tesla</em> customers with FSD-enabled vehicles can also monetize them when they're not in use by lending them to the ride-hailing network.",
#       'sentiment': 0.6573,
#       'highlighted_in': 'main_text'},
#      {'highlight': "Ark's financial models suggest <em>Tesla</em> will generate $1 trillion in annual revenue by 2027, which will value the company at $6.1 trillion (translating to $2,000 per share). Considering <em>Tesla</em> only generated $96.7 billion in revenue during 2023, it would have to grow by a whopping 80% every year between now and 2027 to meet Ark's forecast.",
#       'sentiment': 0.34,
#       'highlighted_in': 'main_text'},
#      {'highlight': "Could <em>Tesla</em> stock rise 1,234% to reach $2,000 one day? It's possible, but several things have to go right, and it certainly doesn't appear likely within Ark's projected time frame.",
#       'sentiment': 0.4854,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': 'bf52e329-bc56-4c94-a04b-e17632a6cf8a',
#   'title': 'Market Today: Tech Giants Reignite AI Craze, Alibaba Continues Winning Streak',
#   'description': 'Weekly Stock Market OverviewThe stock market showed signs of recovery after a slow start to the month, buoyed by positive earnings reports from key companies an',
#   'keywords': "GuruFocus, Article, News, GuruFocus Research, MSFT, GOOG, GOOGL, BABA, BLUE, TSLA, XOM, HES, CVX, BILI, BIDU, JD, NTES, RPTX, FANG, INTC, ABBV, CI, DDC, SWK, PARA, APO, KKR, NVDA, </strong>Themarketreboundedfromthepreviousweek'sdeclines, withbankstocksoutperfor",
#   'snippet': 'Weekly Stock Market Overview\n\nThe stock market showed signs of recovery after a slow start to the month, buoyed by positive earnings reports from key companies ...',
#   'url': 'https://www.gurufocus.com/news/2419941/market-today-tech-giants-reignite-ai-craze-alibaba-continues-winning-streak',
#   'image_url': 'https://static.gurufocus.com/1732803573856661504.png',
#   'language': 'en',
#   'published_at': '2024-04-26T22:40:33.000000Z',
#   'source': 'gurufocus.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 9.713768,
#     'sentiment_score': 0.7306,
#     'highlights': [{'highlight': 'Microsoft (MSFT, Financial), Alphabet (GOOG, Financial), and <em>Tesla</em> (TSLA, Financial) reported gains of 1.8%, 11.5%, and 14.4%, respectively, buoyed by positive reactions to their earnings.',
#       'sentiment': 0.8126,
#       'highlighted_in': 'main_text'},
#      {'highlight': "On the earnings front, <em>Tesla</em> (TSLA, Financial) reported a decline in revenue and earnings per share, marking its lowest EPS in ten quarters. Despite this, the electric vehicle maker's stock surged post-market, indicating investor optimism about its future prospects.",
#       'sentiment': 0.6486,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': '8752a154-cf91-47e0-989a-f0bcbefe89a7',
#   'title': '10 Cathie Wood Stocks Insiders are Selling',
#   'description': 'In this article, we will take a detailed look at the 10 Cathie Wood Stocks Insiders are Selling. For a quick overview of such stocks, read our article 5 Cathie Wood Stocks Insiders are Selling. There was a time Cathie Wood talked about her famous “five-year investment horizon” with confidence, giving investors hope that the high-growth, cash-burning companies she […]',
#   'keywords': '',
#   'snippet': 'In this article, we will take a detailed look at the 10 Cathie Wood Stocks Insiders are Selling. For a quick overview of such stocks, read our article 5 Cathie ...',
#   'url': 'https://finance.yahoo.com/news/10-cathie-wood-stocks-insiders-223235246.html?.tsrc=rss',
#   'image_url': 'https://s.yimg.com/ny/api/res/1.2/wJpXY.G1sirssrat87Z5Mg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD0xNTI0/https://media.zenfs.com/en/insidermonkey.com/4ac74399d4ca5a2a967588e16c8df664',
#   'language': 'en',
#   'published_at': '2024-04-26T22:32:35.000000Z',
#   'source': 'finance.yahoo.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 24.960932,
#     'sentiment_score': 0.40952,
#     'highlights': [{'highlight': "It's heavily invested in <em>Tesla</em> (down 31% YTD) which is getting clobbered amid rising competition in the US and China (Cathie Wood reiterated her $2000 price target on TSLA recently). Half of ARK's innovation fund is invested in just seven stocks.",
#       'sentiment': 0.3818,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Longer term, unlike the history with Cisco, competition could intensify, not only because AMD is finding success but also because Nvidia’s customers—cloud service providers and companies like <em>Tesla</em>—are designing their own AI chips.',
#       'sentiment': 0.6808,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Like ACCD, Cathie Wood is also holding onto <em>Tesla</em> <em>Inc</em> (<em>NASDAQ:TSLA</em>), Coinbase Global Inc (NASDAQ:COIN) and UiPath Inc (NYSE:PATH).\n\n9.',
#       'sentiment': 0.3612,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'In addition to PSTG, Cathie Wood also likes <em>Tesla</em> <em>Inc</em> (<em>NASDAQ:TSLA</em>), Coinbase Global Inc (NASDAQ:COIN) and UiPath Inc (NYSE:PATH).\n\n7.',
#       'sentiment': 0.4215,
#       'highlighted_in': 'main_text'},
#      {'highlight': "In addition to NET, <em>Tesla</em> <em>Inc</em> (<em>NASDAQ:TSLA</em>), Coinbase Global Inc (NASDAQ:COIN) and UiPath Inc (NYSE:PATH) are also important names in Cathie Wood's portfolio.\n\nAs of the end of the fourth quarter of 2023, 44 hedge funds reported owning stakes in Cloudflare Inc (NYSE:NET).",
#       'sentiment': 0.2023,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': 'b387d1e7-0574-4456-a354-e2c71cf4f25a',
#   'title': 'Does Mag 7 Leadership Remain Intact Post-Tesla and Meta Disappointments?',
#   'description': "Two 'Mag 7' members faced selling pressure following the release of their quarterly results, bringing the group's leadership under focus. Was the selling overdone?",
#   'keywords': 'stock, stocks, investment, investment advice, investing, online trading, online investment, online stock trading, stock market, financial, financial planning, quote, quotes, stock quotes',
#   'snippet': 'This page has not been authorized, sponsored, or otherwise approved or endorsed by the companies represented herein. Each of the company logos represented herei...',
#   'url': 'https://www.zacks.com/commentary/2263673/does-mag-7-leadership-remain-intact-post-tesla-and-meta-disappointments?cid=CS-ZC-FT-earnings_preview-2263673',
#   'image_url': 'https://staticx-tuner.zacks.com/images/articles/main/f8/14626.jpg',
#   'language': 'en',
#   'published_at': '2024-04-26T22:23:00.000000Z',
#   'source': 'zacks.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 27.56099,
#     'sentiment_score': -0.296,
#     'highlights': [{'highlight': 'Does Mag 7 Leadership Remain Intact Post-<em>Tesla</em> and Meta Disappointments?',
#       'sentiment': -0.296,
#       'highlighted_in': 'title'}]}],
#   'similar': [{'uuid': 'f0350c44-48f7-4b17-b137-9792ba14dd36',
#     'title': 'Does Mag 7 Leadership Remain Intact Post-Tesla and Meta Disappointments?',
#     'description': "Two 'Mag 7' members faced selling pressure following the release of their quarterly results, bringing the group's leadership under focus. Was the selling overdone?",
#     'keywords': '',
#     'snippet': 'We have Apple and Amazon on deck to report Q1 results this week, and we will need to wait a few more weeks before we see Nvidia’s numbers. But we have already...',
#     'url': 'https://finance.yahoo.com/news/does-mag-7-leadership-remain-222300801.html?.tsrc=rss',
#     'image_url': 'https://media.zenfs.com/en/zacks.com/8e117bda93f994d9da5efbb462a35e4f',
#     'language': 'en',
#     'published_at': '2024-04-26T22:23:00.000000Z',
#     'source': 'finance.yahoo.com',
#     'relevance_score': None,
#     'entities': [{'symbol': '^SPX',
#       'name': 'S&P 500 INDEX',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'index',
#       'industry': 'N/A',
#       'match_score': 19.449661,
#       'sentiment_score': -0.7184,
#       'highlights': [{'highlight': 'Through Friday, April 26th, we have seen Q1 results from 229 <em>S</em>&<em>P</em> <em>500</em> <em>index</em> members, or 45.8% of the index’s total membership. Total Q1 earnings for these 229 index members are up +2.8% from the same period last year on +3.3% higher revenues, with 78.2% beating EPS estimates and 59.8% beating revenue estimates.',
#         'sentiment': -0.7184,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'GOOGL',
#       'name': 'Alphabet Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'equity',
#       'industry': 'Communication Services',
#       'match_score': 24.009914,
#       'sentiment_score': 0.3639,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: <em>Alphabet</em> <em>GOOGL</em>, Microsoft MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the Microsoft and <em>Alphabet</em> reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The <em>Alphabet</em> report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind Microsoft in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with Microsoft and <em>Alphabet</em>, leadership in AI requires a lot of spending. If market participants are okay with Microsoft and <em>Alphabet</em> spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': '(TSLA) : Free Stock Analysis Report\n\n<em>Alphabet</em> <em>Inc</em>. (<em>GOOGL</em>) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.872,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'META',
#       'name': 'Meta Platforms Inc',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'equity',
#       'industry': 'Communication Services',
#       'match_score': 9.064617,
#       'sentiment_score': 0.765,
#       'highlights': [{'highlight': '(GOOGL) : Free Stock Analysis Report\n\n<em>Meta</em> <em>Platforms</em>, <em>Inc</em>. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.765,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'MSFT',
#       'name': 'Microsoft Corporation',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'equity',
#       'industry': 'Technology',
#       'match_score': 13.505636,
#       'sentiment_score': 0.376325,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, <em>Microsoft</em> MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the <em>Microsoft</em> and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The Alphabet report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind <em>Microsoft</em> in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with <em>Microsoft</em> and Alphabet, leadership in AI requires a lot of spending. If market participants are okay with <em>Microsoft</em> and Alphabet spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\n<em>Microsoft</em> <em>Corporation</em> (MSFT) : Free Stock Analysis Report\n\nTesla, Inc. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'TSLA',
#       'name': 'Tesla, Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'equity',
#       'industry': 'Consumer Cyclical',
#       'match_score': 26.85965,
#       'sentiment_score': -0.008114,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, Microsoft MSFT, Meta META, and <em>Tesla</em> TSLA.\n\nIt is hard to find any weakness in the Microsoft and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The market reaction to the <em>Tesla</em> and Meta reports needs to be contextualized.\n\nMeta shares were very strong performers prior to this report, and any way you look at the company’s Q1 results, they are impressive. Meta’s Q1 earnings were up +80.5% from the year-earlier period on +27.3% higher revenues.',
#         'sentiment': 0.8428,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares have been the worst performing of the group, with many starting to speak out that perhaps it didn’t deserve to be part of this group. The stock price weakness reflects the steadily deteriorating earnings outlook, with a combination of softening demand and heightened competitive pressures forcing Elon Musk to cut prices.',
#         'sentiment': -0.836,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nGiven this stock’s price action and estimates revision trajectory coming into the quarterly release, investors were conditioned to expect the worst from <em>Tesla</em>, but the actual results were simply bad (instead of ‘very bad’).',
#         'sentiment': -0.8074,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares are still laggards relative to other Mag 7 stocks, as the year-to-date performance chart shows.',
#         'sentiment': 0.296,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\nMicrosoft Corporation (MSFT) : Free Stock Analysis Report\n\n<em>Tesla</em>, <em>Inc</em>. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Does Mag 7 Leadership Remain Intact Post-<em>Tesla</em> and Meta Disappointments?',
#         'sentiment': -0.296,
#         'highlighted_in': 'title'}]},
#      {'symbol': 'GOOGL.MX',
#       'name': 'Alphabet Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'mx',
#       'type': 'equity',
#       'industry': 'Communication Services',
#       'match_score': 16.680506,
#       'sentiment_score': 0.3639,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: <em>Alphabet</em> GOOGL, Microsoft MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the Microsoft and <em>Alphabet</em> reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The <em>Alphabet</em> report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind Microsoft in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with Microsoft and <em>Alphabet</em>, leadership in AI requires a lot of spending. If market participants are okay with Microsoft and <em>Alphabet</em> spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': '(TSLA) : Free Stock Analysis Report\n\n<em>Alphabet</em> <em>Inc</em>. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.872,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'GOOG.MX',
#       'name': 'Alphabet Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'mx',
#       'type': 'equity',
#       'industry': 'Communication Services',
#       'match_score': 16.680506,
#       'sentiment_score': 0.3639,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: <em>Alphabet</em> GOOGL, Microsoft MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the Microsoft and <em>Alphabet</em> reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The <em>Alphabet</em> report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind Microsoft in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with Microsoft and <em>Alphabet</em>, leadership in AI requires a lot of spending. If market participants are okay with Microsoft and <em>Alphabet</em> spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': '(TSLA) : Free Stock Analysis Report\n\n<em>Alphabet</em> <em>Inc</em>. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.872,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'MSFT.MX',
#       'name': 'Microsoft Corporation',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'mx',
#       'type': 'equity',
#       'industry': 'Technology',
#       'match_score': 13.504007,
#       'sentiment_score': 0.376325,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, <em>Microsoft</em> MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the <em>Microsoft</em> and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The Alphabet report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind <em>Microsoft</em> in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with <em>Microsoft</em> and Alphabet, leadership in AI requires a lot of spending. If market participants are okay with <em>Microsoft</em> and Alphabet spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\n<em>Microsoft</em> <em>Corporation</em> (MSFT) : Free Stock Analysis Report\n\nTesla, Inc. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': '^GSPC',
#       'name': 'S&P 500',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'index',
#       'industry': 'N/A',
#       'match_score': 31.805405,
#       'sentiment_score': 0.20515,
#       'highlights': [{'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nPlease note that the Mag 7 companies currently account for 29.1% of the <em>S</em>&<em>P</em> <em>500</em> index’s total market capitalization and are expected to bring in 20.6% of the index’s total earnings in 2024.',
#         'sentiment': 0.3182,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'For 2023 Q4, the Mag 7 group has a bigger weightage, bringing in 21.6% of all <em>S</em>&<em>P</em> <em>500</em> earnings.\n\nThe chart below shows the group’s earnings contribution to the index over time and what is currently expected for the next two years.',
#         'sentiment': 0,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nEarnings Season Scorecard and This Week’s Earnings Reports\n\nWe remain in the heart of the Q1 earnings season this week, with more than 950 companies reporting results, including 177 <em>S</em>&<em>P</em> <em>500</em> members.',
#         'sentiment': 0.6369,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Through Friday, April 26th, we have seen Q1 results from 229 <em>S</em>&<em>P</em> <em>500</em> index members, or 45.8% of the index’s total membership. Total Q1 earnings for these 229 index members are up +2.8% from the same period last year on +3.3% higher revenues, with 78.2% beating EPS estimates and 59.8% beating revenue estimates.',
#         'sentiment': -0.7184,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nThe Earnings Big Picture\n\nLooking at Q1 as a whole, total <em>S</em>&<em>P</em> <em>500</em> earnings are expected to be up +3.8% from the same period last year on +3.7% higher revenues, which would follow the +6.8% earnings growth on +3.3% revenue gains in the preceding period.',
#         'sentiment': 0.6124,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nLooking at the overall earnings picture on an annual basis, total 2024 <em>S</em>&<em>P</em> <em>500</em> earnings are expected to be up +8.3% on +1.7% revenue growth.',
#         'sentiment': 0.3818,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'TSLA.MX',
#       'name': 'Tesla, Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'mx',
#       'type': 'equity',
#       'industry': 'Consumer Cyclical',
#       'match_score': 26.860092,
#       'sentiment_score': -0.008114,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, Microsoft MSFT, Meta META, and <em>Tesla</em> TSLA.\n\nIt is hard to find any weakness in the Microsoft and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The market reaction to the <em>Tesla</em> and Meta reports needs to be contextualized.\n\nMeta shares were very strong performers prior to this report, and any way you look at the company’s Q1 results, they are impressive. Meta’s Q1 earnings were up +80.5% from the year-earlier period on +27.3% higher revenues.',
#         'sentiment': 0.8428,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares have been the worst performing of the group, with many starting to speak out that perhaps it didn’t deserve to be part of this group. The stock price weakness reflects the steadily deteriorating earnings outlook, with a combination of softening demand and heightened competitive pressures forcing Elon Musk to cut prices.',
#         'sentiment': -0.836,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nGiven this stock’s price action and estimates revision trajectory coming into the quarterly release, investors were conditioned to expect the worst from <em>Tesla</em>, but the actual results were simply bad (instead of ‘very bad’).',
#         'sentiment': -0.8074,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares are still laggards relative to other Mag 7 stocks, as the year-to-date performance chart shows.',
#         'sentiment': 0.296,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\nMicrosoft Corporation (MSFT) : Free Stock Analysis Report\n\n<em>Tesla</em>, <em>Inc</em>. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Does Mag 7 Leadership Remain Intact Post-<em>Tesla</em> and Meta Disappointments?',
#         'sentiment': -0.296,
#         'highlighted_in': 'title'}]},
#      {'symbol': 'MSF.BR',
#       'name': 'Microsoft Corporation',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'be',
#       'type': 'equity',
#       'industry': 'Technology',
#       'match_score': 13.504137,
#       'sentiment_score': 0.376325,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, <em>Microsoft</em> MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the <em>Microsoft</em> and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The Alphabet report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind <em>Microsoft</em> in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with <em>Microsoft</em> and Alphabet, leadership in AI requires a lot of spending. If market participants are okay with <em>Microsoft</em> and Alphabet spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\n<em>Microsoft</em> <em>Corporation</em> (MSFT) : Free Stock Analysis Report\n\nTesla, Inc. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'TSLA34.SA',
#       'name': 'Tesla, Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'br',
#       'type': 'equity',
#       'industry': 'Consumer Cyclical',
#       'match_score': 26.860119,
#       'sentiment_score': -0.008114,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, Microsoft MSFT, Meta META, and <em>Tesla</em> TSLA.\n\nIt is hard to find any weakness in the Microsoft and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The market reaction to the <em>Tesla</em> and Meta reports needs to be contextualized.\n\nMeta shares were very strong performers prior to this report, and any way you look at the company’s Q1 results, they are impressive. Meta’s Q1 earnings were up +80.5% from the year-earlier period on +27.3% higher revenues.',
#         'sentiment': 0.8428,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares have been the worst performing of the group, with many starting to speak out that perhaps it didn’t deserve to be part of this group. The stock price weakness reflects the steadily deteriorating earnings outlook, with a combination of softening demand and heightened competitive pressures forcing Elon Musk to cut prices.',
#         'sentiment': -0.836,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nGiven this stock’s price action and estimates revision trajectory coming into the quarterly release, investors were conditioned to expect the worst from <em>Tesla</em>, but the actual results were simply bad (instead of ‘very bad’).',
#         'sentiment': -0.8074,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares are still laggards relative to other Mag 7 stocks, as the year-to-date performance chart shows.',
#         'sentiment': 0.296,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\nMicrosoft Corporation (MSFT) : Free Stock Analysis Report\n\n<em>Tesla</em>, <em>Inc</em>. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Does Mag 7 Leadership Remain Intact Post-<em>Tesla</em> and Meta Disappointments?',
#         'sentiment': -0.296,
#         'highlighted_in': 'title'}]},
#      {'symbol': 'GOOGL.BA',
#       'name': 'Alphabet Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'ar',
#       'type': 'equity',
#       'industry': 'Communication Services',
#       'match_score': 16.679482,
#       'sentiment_score': 0.3639,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: <em>Alphabet</em> GOOGL, Microsoft MSFT, Meta META, and Tesla TSLA.\n\nIt is hard to find any weakness in the Microsoft and <em>Alphabet</em> reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The <em>Alphabet</em> report appears to reassure investors that it has a credible AI strategy in place and may not be that far behind Microsoft in this critical race.\n\nThe market reaction to the Tesla and Meta reports needs to be contextualized.',
#         'sentiment': 0.34,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'But as we are seeing with Microsoft and <em>Alphabet</em>, leadership in AI requires a lot of spending. If market participants are okay with Microsoft and <em>Alphabet</em> spending hands-over-fist on AI, then they should also be okay with Meta.',
#         'sentiment': 0.4215,
#         'highlighted_in': 'main_text'},
#        {'highlight': '(TSLA) : Free Stock Analysis Report\n\n<em>Alphabet</em> <em>Inc</em>. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.872,
#         'highlighted_in': 'main_text'}]},
#      {'symbol': 'TSLAD.BA',
#       'name': 'TESLA INC',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'ar',
#       'type': 'equity',
#       'industry': 'N/A',
#       'match_score': 26.860687,
#       'sentiment_score': -0.008114,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, Microsoft MSFT, Meta META, and <em>Tesla</em> TSLA.\n\nIt is hard to find any weakness in the Microsoft and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The market reaction to the <em>Tesla</em> and Meta reports needs to be contextualized.\n\nMeta shares were very strong performers prior to this report, and any way you look at the company’s Q1 results, they are impressive. Meta’s Q1 earnings were up +80.5% from the year-earlier period on +27.3% higher revenues.',
#         'sentiment': 0.8428,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares have been the worst performing of the group, with many starting to speak out that perhaps it didn’t deserve to be part of this group. The stock price weakness reflects the steadily deteriorating earnings outlook, with a combination of softening demand and heightened competitive pressures forcing Elon Musk to cut prices.',
#         'sentiment': -0.836,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nGiven this stock’s price action and estimates revision trajectory coming into the quarterly release, investors were conditioned to expect the worst from <em>Tesla</em>, but the actual results were simply bad (instead of ‘very bad’).',
#         'sentiment': -0.8074,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares are still laggards relative to other Mag 7 stocks, as the year-to-date performance chart shows.',
#         'sentiment': 0.296,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\nMicrosoft Corporation (MSFT) : Free Stock Analysis Report\n\n<em>Tesla</em>, <em>Inc</em>. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Does Mag 7 Leadership Remain Intact Post-<em>Tesla</em> and Meta Disappointments?',
#         'sentiment': -0.296,
#         'highlighted_in': 'title'}]},
#      {'symbol': 'TSLAC.BA',
#       'name': 'TESLA INC',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'ar',
#       'type': 'equity',
#       'industry': 'N/A',
#       'match_score': 26.860687,
#       'sentiment_score': -0.008114,
#       'highlights': [{'highlight': 'But we have already seen Q1 results from the other four members of the ‘Magnificent 7’ group: Alphabet GOOGL, Microsoft MSFT, Meta META, and <em>Tesla</em> TSLA.\n\nIt is hard to find any weakness in the Microsoft and Alphabet reports, and the market’s reaction to these two reports shows that investors agree with that assessment.',
#         'sentiment': -0.1779,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'The market reaction to the <em>Tesla</em> and Meta reports needs to be contextualized.\n\nMeta shares were very strong performers prior to this report, and any way you look at the company’s Q1 results, they are impressive. Meta’s Q1 earnings were up +80.5% from the year-earlier period on +27.3% higher revenues.',
#         'sentiment': 0.8428,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares have been the worst performing of the group, with many starting to speak out that perhaps it didn’t deserve to be part of this group. The stock price weakness reflects the steadily deteriorating earnings outlook, with a combination of softening demand and heightened competitive pressures forcing Elon Musk to cut prices.',
#         'sentiment': -0.836,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Zacks Investment Research\n\n\n\nImage Source: Zacks Investment Research\n\nGiven this stock’s price action and estimates revision trajectory coming into the quarterly release, investors were conditioned to expect the worst from <em>Tesla</em>, but the actual results were simply bad (instead of ‘very bad’).',
#         'sentiment': -0.8074,
#         'highlighted_in': 'main_text'},
#        {'highlight': '<em>Tesla</em> shares are still laggards relative to other Mag 7 stocks, as the year-to-date performance chart shows.',
#         'sentiment': 0.296,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Click to get this free report\n\nMicrosoft Corporation (MSFT) : Free Stock Analysis Report\n\n<em>Tesla</em>, <em>Inc</em>. (TSLA) : Free Stock Analysis Report\n\nAlphabet Inc. (GOOGL) : Free Stock Analysis Report\n\nMeta Platforms, Inc. (META) : Free Stock Analysis Report\n\nTo read this article on Zacks.com click here.\n\nZacks Investment Research',
#         'sentiment': 0.9217,
#         'highlighted_in': 'main_text'},
#        {'highlight': 'Does Mag 7 Leadership Remain Intact Post-<em>Tesla</em> and Meta Disappointments?',
#         'sentiment': -0.296,
#         'highlighted_in': 'title'}]},
#      {'symbol': 'GOGLD.BA',
#       'name': 'ALPHABET INC',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'ar',
#       'type': 'equity',
# ...
#   'url': 'https://www.investing.com/news/stock-market-news/everyone-said-sell-tesla-ahead-of-earnings-our-ai-model-disagreed--heres-why-3393527',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXNPEE310MM_L.jpg',
#   'language': 'en',
#   'published_at': '2024-04-24T11:53:17.000000Z',
#   'source': 'investing.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 27.161015,
#     'sentiment_score': 0.049267,
#     'highlights': [{'highlight': 'Investing.com — After a consolidation period amid heightened risks associated with the EV industry and growing competition with China, <em>Tesla</em> (NASDAQ: ) stock is posting a substantial rebound today.',
#       'sentiment': 0.1027,
#       'highlighted_in': 'main_text'},
#      {'highlight': "But did you buy the <em>Tesla</em> dip?\n\nWell, I wouldn't blame you if you didn't. In fact, virtually every analyst out there was telling you to sell the stock over the last week.",
#       'sentiment': 0.3633,
#       'highlighted_in': 'main_text'},
#      {'highlight': "Everyone said 'sell <em>Tesla</em>' ahead of earnings; our AI model disagreed",
#       'sentiment': -0.3182,
#       'highlighted_in': 'title'}]}],
#   'similar': []},
#  {'uuid': '9eed0a00-5837-44ca-a83d-274aebf771c9',
#   'title': 'Tesla stock targets slashed across Wall Street after earnings miss By Investing.com',
#   'description': 'Tesla stock targets slashed across Wall Street after earnings miss',
#   'keywords': '',
#   'snippet': "In the wake of Tesla (NASDAQ: )'s earnings report after the close on Tuesday, which fell short of analyst expectations, Wall Street is witnessing a downward rev...",
#   'url': 'https://www.investing.com/news/stock-market-news/tesla-stock-targets-slashed-across-wall-street-after-earnings-miss-3393508',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXMPEE6H1AX_L.jpg',
#   'language': 'en',
#   'published_at': '2024-04-24T11:44:18.000000Z',
#   'source': 'investing.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 36.30662,
#     'sentiment_score': -0.11455,
#     'highlights': [{'highlight': "In the wake of <em>Tesla</em> (NASDAQ: )'s earnings report after the close on Tuesday, which fell short of analyst expectations, Wall Street is witnessing a downward revision in stock targets for the electric vehicle giant.",
#       'sentiment': 0,
#       'highlighted_in': 'main_text'},
#      {'highlight': '<em>Tesla</em> earnings breakdown\n\n<em>Tesla</em> (<em>NASDAQ</em>: <em>TSLA</em>) reported first-quarter EPS of $0.45, $0.04 worse than the analyst estimate of $0.49. Revenue for the quarter was $21.3 billion versus the consensus estimate of $22.27 billion.',
#       'sentiment': -0.4767,
#       'highlighted_in': 'main_text'},
#      {'highlight': "Despite the earnings and revenue miss, <em>Tesla</em> shares are up more than 11% premarket Wednesday, trading above the $161 per share mark.\n\nThe EV maker's announcement that it was speeding up the launch of a new model overshadowed its results, boosting the stock price in the process.",
#       'sentiment': 0.6369,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Despite investor concerns and reports that the EV maker could scrap plans for a cheaper EV, <em>Tesla</em> touted the launch of new models.\n\n"We have updated our future vehicle line-up to accelerate the launch of new models ahead of our previously communicated start of production in the second half of 2025," the company said.',
#       'sentiment': -0.0516,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Analysts cut <em>Tesla</em> stock targets\n\nReacting to the earnings release, analysts at UBS cut their price target for <em>Tesla</em> to $147 from $160 per share, maintaining a Neutral rating on the stock.',
#       'sentiment': -0.25,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Meanwhile, analysts at Canaccord cut their <em>Tesla</em> price target to $220 from $234, but the firm held its Buy rating on the stock.\n\n“New, fuller information from management helped to at least partially solidify both the near-term and longer-term earnings trajectories of the firm — that had been so muddied over the last few weeks,” said Canaccord.',
#       'sentiment': -0.1406,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Truist cut its <em>Tesla</em> price target to $162 from $176, keeping a Hold rating on the stock.',
#       'sentiment': -0.2732,
#       'highlighted_in': 'main_text'},
#      {'highlight': '<em>Tesla</em> stock targets slashed across Wall Street after earnings miss By Investing.com',
#       'sentiment': -0.3612,
#       'highlighted_in': 'title'}]}],
#   'similar': []},
#  {'uuid': '647dd010-db33-4fb3-ad7e-92ffbaa834a2',
#   'title': 'Meta’s $350 Billion Rally to Collide With Lofty AI Expectations',
#   'description': '(Bloomberg) -- When it comes to social-media stocks, there’s Meta Platforms Inc., and then there’s everyone else.Most Read from BloombergTaylor Swift Is Proof That How We Critique Music Is BrokenBiden’s New Chopper Is Demoted After Scorching White House LawnTesla Speeds Cheaper EV Plans, Calming Fears Over StrategyBillionaire Pinaults Fight to Pull Gucci Off the Discount RackRay Dalio’s Famous Trade Is Sputtering, Investors BailingThe Facebook parent has been the best-performer in the sector thi',
#   'keywords': '',
#   'snippet': '(Bloomberg) -- When it comes to social-media stocks, there’s Meta Platforms Inc., and then there’s everyone else.\n\nMost Read from Bloomberg\n\nThe Facebook pa...',
#   'url': 'https://finance.yahoo.com/news/meta-350-billion-rally-collide-113703472.html?.tsrc=rss',
#   'image_url': 'https://media.zenfs.com/en/bloomberg_markets_842/6f2cc460d63f6d3ec938770f27eb2586',
#   'language': 'en',
#   'published_at': '2024-04-24T11:37:03.000000Z',
#   'source': 'finance.yahoo.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 16.534956,
#     'sentiment_score': 0.7351,
#     'highlights': [{'highlight': 'Tech Chart of the Day\n\n<em>Tesla</em> <em>Inc</em>. shares rebounded after Elon Musk vowed to launch less-expensive vehicles as soon as late this year, easing concerns about disappointing earnings results and diminished growth prospects. If the 11% gain in premarket trading holds, <em>Tesla</em> will be set for its biggest rise since January 2023.',
#       'sentiment': 0.7351,
#       'highlighted_in': 'main_text'}]}],
#   'similar': []},
#  {'uuid': 'e6e28a1b-4585-4625-ad78-e705dda02f4a',
#   'title': 'Tesla accelerates affordable car launch after disappointing Q1',
#   'description': 'Tesla Inc. races to reignite demand with an ambitious move: expediting the launch of more affordable vehicles to hit the market this year.',
#   'keywords': '',
#   'snippet': 'Tesla Inc. races to reignite demand with an ambitious move: expediting the launch of more affordable vehicles to hit the market this year, a sharp departure fro...',
#   'url': 'https://www.biznews.com/global-investing/2024/04/24/tesla-accelerates-affordable-car-launch',
#   'image_url': 'https://www.biznews.com/wp-content/uploads/2024/04/Untitled-design-18-1.png',
#   'language': 'en',
#   'published_at': '2024-04-24T11:23:31.000000Z',
#   'source': 'biznews.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 33.01261,
#     'sentiment_score': -0.123433,
#     'highlights': [{'highlight': '<em>Tesla</em> <em>Inc</em>. races to reignite demand with an ambitious move: expediting the launch of more affordable vehicles to hit the market this year, a sharp departure from its previous timeline. Despite a lacklustre quarter, marked by earnings and sales shortfalls, the announcement sends <em>Tesla</em> shares soaring.',
#       'sentiment': 0.5859,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'By Dana Hull and Ed Ludlow\n\n<em>Tesla</em> <em>Inc</em>. is accelerating the launch of less-expensive cars in a bid to revive sagging demand following another disappointing quarter.\n\nThe electric-vehicle maker aims to start production of new models as soon as this year, well ahead of the late-2025 timing it had previously pledged.',
#       'sentiment': -0.3182,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Investors have been worried that <em>Tesla</em> had killed plans for a long-promised, $25,000 car as Musk pursued his robotaxi vision. Now <em>Tesla</em> says it’s accelerating low cost plans — and can build the new cars at existing factories.',
#       'sentiment': -0.7783,
#       'highlighted_in': 'main_text'},
#      {'highlight': '<em>Tesla</em> gave no timeline, but said it’s continuing to pursue a new module-based “unboxed” manufacturing process for its promised robotaxi model. In a reflection of leaner times, <em>Tesla</em> noted those new models will be built on existing manufacturing lines at current factories to maximize capacity and grow “prudently.”',
#       'sentiment': 0.3919,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Earlier this month, <em>Tesla</em> initiated its largest-ever round of layoffs, cutting more than 10% of positions — though Bloomberg has reported the company may ultimately let go some 20% of its staff. At the same time, two senior executives quit, raising questions about who is in charge of key initiatives.',
#       'sentiment': -0.128,
#       'highlighted_in': 'main_text'},
#      {'highlight': '<em>Tesla</em> accelerates affordable car launch after disappointing Q1',
#       'sentiment': -0.4939,
#       'highlighted_in': 'title'}]}],
#   'similar': []},
#  {'uuid': '3630d20f-4bbf-4d55-97c0-da3bc4bf1c9d',
#   'title': 'Tesla (TSLA) Soars 13.1% After-Hours on Affordable EV Promise',
#   'description': "Tesla's (TSLA) shares soared in the after-hours trading after the EV-maker doubled down on its promise of a mass-market electric car, squashing reports of cancellation.",
#   'keywords': 'stock, stocks, investment, investment advice, investing, online trading, online investment, online stock trading, stock market, financial, financial planning, quote, quotes, stock quotes',
#   'snippet': 'This page has not been authorized, sponsored, or otherwise approved or endorsed by the companies represented herein. Each of the company logos represented herei...',
#   'url': 'https://www.zacks.com/stock/news/2260865/tesla-tsla-soars-131-after-hours-on-affordable-ev-promise?cid=CS-ZC-FT-analyst_blog|company_news_-_corporate_actions-2260865',
#   'image_url': 'https://staticx-tuner.zacks.com/images/articles/main/bc/108.jpg',
#   'language': 'en',
#   'published_at': '2024-04-24T11:20:00.000000Z',
#   'source': 'zacks.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 28.267044,
#     'sentiment_score': 0.3182,
#     'highlights': [{'highlight': '<em>Tesla</em> (TSLA) Soars 13.1% After-Hours on Affordable EV Promise',
#       'sentiment': 0.3182,
#       'highlighted_in': 'title'}]}],
#   'similar': [{'uuid': '1e745df7-7c7d-4647-a948-02739cf7dea7',
#     'title': 'Tesla (TSLA) Q1 Earnings Miss Expectations, Decline Y/Y',
#     'description': 'Tesla (TSLA) misses top- and bottom-line estimates for the first quarter on lower year-over-year unit sales.',
#     'keywords': 'stock, stocks, investment, investment advice, investing, online trading, online investment, online stock trading, stock market, financial, financial planning, quote, quotes, stock quotes',
#     'snippet': 'This page has not been authorized, sponsored, or otherwise approved or endorsed by the companies represented herein. Each of the company logos represented herei...',
#     'url': 'https://www.zacks.com/stock/news/2260780/tesla-tsla-q1-earnings-miss-expectations-decline-yy?cid=CS-ZC-FT-analyst_blog|earnings_article-2260780',
#     'image_url': 'https://staticx-tuner.zacks.com/images/articles/main/b9/441.jpg',
#     'language': 'en',
#     'published_at': '2024-04-24T09:36:00.000000Z',
#     'source': 'zacks.com',
#     'relevance_score': None,
#     'entities': [{'symbol': 'TSLA',
#       'name': 'Tesla, Inc.',
#       'exchange': None,
#       'exchange_long': None,
#       'country': 'us',
#       'type': 'equity',
#       'industry': 'Consumer Cyclical',
#       'match_score': 29.060385,
#       'sentiment_score': -0.1531,
#       'highlights': [{'highlight': '<em>Tesla</em> (TSLA) Q1 Earnings Miss Expectations, Decline Y/Y',
#         'sentiment': -0.1531,
#         'highlighted_in': 'title'}]}]}]},
#  {'uuid': 'a4a7c4bf-b2ae-4208-8ad2-531e22687b58',
#   'title': 'Tesla (TSLA) Soars 13.1% After-Hours on Affordable EV Promise',
#   'description': "Tesla's (TSLA) shares soared in the after-hours trading after the EV-maker doubled down on its promise of a mass-market electric car, squashing reports of cancellation.",
#   'keywords': '',
#   'snippet': 'Tesla, Inc.’s TSLA shares rose 2.2% in the last session but soared 13.1% in the after-hours following its first-quarter 2024 earnings. This happened despite t...',
#   'url': 'https://finance.yahoo.com/news/tesla-tsla-soars-13-1-112000103.html?.tsrc=rss',
#   'image_url': 'https://media.zenfs.com/en/zacks.com/d850dfc39ab42c200d33e4fd177f419b',
#   'language': 'en',
#   'published_at': '2024-04-24T11:20:00.000000Z',
#   'source': 'finance.yahoo.com',
#   'relevance_score': None,
#   'entities': [{'symbol': 'TSLA',
#     'name': 'Tesla, Inc.',
#     'exchange': None,
#     'exchange_long': None,
#     'country': 'us',
#     'type': 'equity',
#     'industry': 'Consumer Cyclical',
#     'match_score': 33.11187,
#     'sentiment_score': 0.18488,
#     'highlights': [{'highlight': '<em>Tesla</em>, <em>Inc</em>.’s TSLA shares rose 2.2% in the last session but soared 13.1% in the after-hours following its first-quarter 2024 earnings. This happened despite the electric vehicles (EV) giant missing both earnings and revenue estimates for the quarter.',
#       'sentiment': -0.296,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'Earlier in the month, there were reports that <em>Tesla</em> has shut down its inexpensive car project, the one that investors had been counting on for long to finally catapult it into becoming a mass-market automaker.',
#       'sentiment': 0,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'BYD Auto from China has surpassed <em>Tesla</em> as the global market leader in the EV segment. Ford, General Motors and Mercedes each carry a Zacks #3 (Hold) currently. In the near term, it will be essential to follow this space to check the emergence of newer, non-traditional automakers that have entered the EV space.',
#       'sentiment': 0,
#       'highlighted_in': 'main_text'},
#      {'highlight': 'However, the spotlight today is fixed on <em>Tesla</em>.\n\nStory continues\n\nWant the latest recommendations from Zacks Investment Research? Today, you can download 7 Best Stocks for the Next 30 Days. Click to get this free report\n\nFord Motor Company (F) : Free Stock Analysis Report\n\nGeneral Motors Company (GM) : Free Stock Analysis Report\n\n<em>Tesla</em>, <em>Inc</em>.',
#       'sentiment': 0.9022,
#       'highlighted_in': 'main_text'},
#      {'highlight': '<em>Tesla</em> (TSLA) Soars 13.1% After-Hours on Affordable EV Promise',
#       'sentiment': 0.3182,
#       'highlighted_in': 'title'}]}],
#   'similar': []}]

# %%
import json

# Save to JSON
with open('tesla_articles.json', 'w') as f:
    json.dump(all_articles, f)

# %%
import pandas as pd 
# Load JSON data
with open('tesla_articles.json', 'r') as file:
    articles = json.load(file)

# Convert to DataFrame for easier manipulation and analysis
articles_df = pd.DataFrame(articles)
print(articles_df.head())
print(articles_df.describe())
# Out:
#                                    uuid  \
# 0  f21ee777-8ceb-4352-8ead-088f094078a6
# 1  91bb4b80-a1db-465e-ab05-10978878a910
# 2  88ceedc6-4582-4c58-9ee6-7aea4b6e1953
# 3  06141a58-09c6-45a9-831b-0e41c471de49
# 4  bf52e329-bc56-4c94-a04b-e17632a6cf8a
#
#                                                title  \
# 0  S&P's Risk-On Momentum Gets Added Boost From R...
# 1  The "Magnificent Seven" Day of Reckoning Has A...
# 2          Wall Street Breakfast: What Moved Markets
# 3  1 "Magnificent Seven" Stock With 1,234% Upside...
# 4  Market Today: Tech Giants Reignite AI Craze, A...
#
#                                          description  \
# 0  With the quarterly reporting season roughly ha...
# 1  The Nasdaq Composite just posted its worst wee...
# 2  The U.S. stocks rebounded this week amid posit...
# 3  Tesla is the worst-performing stock in the "Ma...
# 4  Weekly Stock Market OverviewThe stock market s...
#
#                                             keywords  \
# 0
# 1
# 2
# 3
# 4  GuruFocus, Article, News, GuruFocus Research, ...
#
#                                              snippet  \
# 0  This advertisement has not loaded yet, but you...
# 1  The Nasdaq Composite just posted its worst wee...
# 2  What a difference a week can make! After posti...
# 3  Tesla is the worst-performing stock in the "Ma...
# 4  Weekly Stock Market Overview\n\nThe stock mark...
#
#                                                  url  \
# 0  https://financialpost.com/pmn/business-pmn/sps...
# 1  https://www.fool.com/investing/2024/04/27/the-...
# 2  https://seekingalpha.com/article/4686982-wall-...
# 3  https://www.fool.com/investing/2024/04/27/1-ma...
# 4  https://www.gurufocus.com/news/2419941/market-...
#
#                                            image_url language  \
# 0  https://smartcdn.gprod.postmedia.digital/finan...       en
# 1  https://g.foolcdn.com/editorial/images/773665/...       en
# 2  https://static.seekingalpha.com/cdn/s3/uploads...       en
# 3  https://g.foolcdn.com/editorial/images/774335/...       en
# 4  https://static.gurufocus.com/17328035738566615...       en
#
#                   published_at             source relevance_score  \
# 0  2024-04-27T12:50:04.000000Z  financialpost.com            None
# 1  2024-04-27T12:10:00.000000Z  finance.yahoo.com            None
# 2  2024-04-27T10:39:22.000000Z   seekingalpha.com            None
# 3  2024-04-27T10:16:00.000000Z  finance.yahoo.com            None
# 4  2024-04-26T22:40:33.000000Z      gurufocus.com            None
#
#                                             entities similar
# 0  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...      []
# 1  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...      []
# 2  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...      []
# 3  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...      []
# 4  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...      []
#                                         uuid  \
# count                                    180
# unique                                   180
# top     f21ee777-8ceb-4352-8ead-088f094078a6
# freq                                       1
#
#                                                     title description  \
# count                                                 180         180
# unique                                                176         163
# top     Tesla (TSLA) Soars 13.1% After-Hours on Afford...
# freq                                                    2           8
#
#        keywords                                            snippet  \
# count       180                                                180
# unique       25                                                172
# top              This page has not been authorized, sponsored, ...
# freq        145                                                  4
#
#                                                       url  \
# count                                                 180
# unique                                                180
# top     https://financialpost.com/pmn/business-pmn/sps...
# freq                                                    1
#
#                                                 image_url language  \
# count                                                 180      180
# unique                                                161        1
# top     https://static.gurufocus.com/17328008832525885...       en
# freq                                                    3      180
#
#                        published_at             source relevance_score  \
# count                           180                180               0
# unique                          176                 32               0
# top     2024-04-24T12:00:00.000000Z  finance.yahoo.com             NaN
# freq                              3                 40             NaN
#
#                                                  entities similar
# count                                                 180     180
# unique                                                179      20
# top     [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...      []
# freq                                                    2     161

# %%
# Example of removing duplicates
articles_df.drop_duplicates(subset=['title'], inplace=True)

# Check for missing values
print(articles_df.isnull().sum())
# Out:
# uuid                 0
# title                0
# description          0
# keywords             0
# snippet              0
# url                  0
# image_url            0
# language             0
# published_at         0
# source               0
# relevance_score    176
# entities             0
# similar              0
# dtype: int64

# %%
# Convert the date column to datetime
articles_df['published_at'] = pd.to_datetime(articles_df['published_at'])

# Find the last fetched date
last_fetched_date = articles_df['published_at'].max()
print("Last fetched date:", last_fetched_date)
# Out:
# Last fetched date: 2024-04-27 12:50:04+00:00

# %%
articles_df
# Out:
#                                      uuid  \
# 0    f21ee777-8ceb-4352-8ead-088f094078a6
# 1    91bb4b80-a1db-465e-ab05-10978878a910
# 2    88ceedc6-4582-4c58-9ee6-7aea4b6e1953
# 3    06141a58-09c6-45a9-831b-0e41c471de49
# 4    bf52e329-bc56-4c94-a04b-e17632a6cf8a
# ..                                    ...
# 174  dfa721c1-bdd6-4c9e-b79d-975d264c1ac2
# 175  9eed0a00-5837-44ca-a83d-274aebf771c9
# 176  647dd010-db33-4fb3-ad7e-92ffbaa834a2
# 177  e6e28a1b-4585-4625-ad78-e705dda02f4a
# 178  3630d20f-4bbf-4d55-97c0-da3bc4bf1c9d
#
#                                                  title  \
# 0    S&P's Risk-On Momentum Gets Added Boost From R...
# 1    The "Magnificent Seven" Day of Reckoning Has A...
# 2            Wall Street Breakfast: What Moved Markets
# 3    1 "Magnificent Seven" Stock With 1,234% Upside...
# 4    Market Today: Tech Giants Reignite AI Craze, A...
# ..                                                 ...
# 174  Everyone said 'sell Tesla' ahead of earnings; ...
# 175  Tesla stock targets slashed across Wall Street...
# 176  Meta’s $350 Billion Rally to Collide With Loft...
# 177  Tesla accelerates affordable car launch after ...
# 178  Tesla (TSLA) Soars 13.1% After-Hours on Afford...
#
#                                            description  \
# 0    With the quarterly reporting season roughly ha...
# 1    The Nasdaq Composite just posted its worst wee...
# 2    The U.S. stocks rebounded this week amid posit...
# 3    Tesla is the worst-performing stock in the "Ma...
# 4    Weekly Stock Market OverviewThe stock market s...
# ..                                                 ...
# 174  Everyone said 'sell Tesla' ahead of earnings; ...
# 175  Tesla stock targets slashed across Wall Street...
# 176  (Bloomberg) -- When it comes to social-media s...
# 177  Tesla Inc. races to reignite demand with an am...
# 178  Tesla's (TSLA) shares soared in the after-hour...
#
#                                               keywords  \
# 0
# 1
# 2
# 3
# 4    GuruFocus, Article, News, GuruFocus Research, ...
# ..                                                 ...
# 174
# 175
# 176
# 177
# 178  stock, stocks, investment, investment advice, ...
#
#                                                snippet  \
# 0    This advertisement has not loaded yet, but you...
# 1    The Nasdaq Composite just posted its worst wee...
# 2    What a difference a week can make! After posti...
# 3    Tesla is the worst-performing stock in the "Ma...
# 4    Weekly Stock Market Overview\n\nThe stock mark...
# ..                                                 ...
# 174  Investing.com — After a consolidation period a...
# 175  In the wake of Tesla (NASDAQ: )'s earnings rep...
# 176  (Bloomberg) -- When it comes to social-media s...
# 177  Tesla Inc. races to reignite demand with an am...
# 178  This page has not been authorized, sponsored, ...
#
#                                                    url  \
# 0    https://financialpost.com/pmn/business-pmn/sps...
# 1    https://www.fool.com/investing/2024/04/27/the-...
# 2    https://seekingalpha.com/article/4686982-wall-...
# 3    https://www.fool.com/investing/2024/04/27/1-ma...
# 4    https://www.gurufocus.com/news/2419941/market-...
# ..                                                 ...
# 174  https://www.investing.com/news/stock-market-ne...
# 175  https://www.investing.com/news/stock-market-ne...
# 176  https://finance.yahoo.com/news/meta-350-billio...
# 177  https://www.biznews.com/global-investing/2024/...
# 178  https://www.zacks.com/stock/news/2260865/tesla...
#
#                                              image_url language  \
# 0    https://smartcdn.gprod.postmedia.digital/finan...       en
# 1    https://g.foolcdn.com/editorial/images/773665/...       en
# 2    https://static.seekingalpha.com/cdn/s3/uploads...       en
# 3    https://g.foolcdn.com/editorial/images/774335/...       en
# 4    https://static.gurufocus.com/17328035738566615...       en
# ..                                                 ...      ...
# 174  https://i-invdn-com.investing.com/news/LYNXNPE...       en
# 175  https://i-invdn-com.investing.com/news/LYNXMPE...       en
# 176  https://media.zenfs.com/en/bloomberg_markets_8...       en
# 177  https://www.biznews.com/wp-content/uploads/202...       en
# 178  https://staticx-tuner.zacks.com/images/article...       en
#
#                  published_at             source relevance_score  \
# 0   2024-04-27 12:50:04+00:00  financialpost.com            None
# 1   2024-04-27 12:10:00+00:00  finance.yahoo.com            None
# 2   2024-04-27 10:39:22+00:00   seekingalpha.com            None
# 3   2024-04-27 10:16:00+00:00  finance.yahoo.com            None
# 4   2024-04-26 22:40:33+00:00      gurufocus.com            None
# ..                        ...                ...             ...
# 174 2024-04-24 11:53:17+00:00      investing.com            None
# 175 2024-04-24 11:44:18+00:00      investing.com            None
# 176 2024-04-24 11:37:03+00:00  finance.yahoo.com            None
# 177 2024-04-24 11:23:31+00:00        biznews.com            None
# 178 2024-04-24 11:20:00+00:00          zacks.com            None
#
#                                               entities  \
# 0    [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 1    [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 2    [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 3    [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 4    [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# ..                                                 ...
# 174  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 175  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 176  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 177  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
# 178  [{'symbol': 'TSLA', 'name': 'Tesla, Inc.', 'ex...
#
#                                                similar
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 174                                                 []
# 175                                                 []
# 176                                                 []
# 177                                                 []
# 178  [{'uuid': '1e745df7-7c7d-4647-a948-02739cf7dea...
#
# [176 rows x 13 columns]

# %%
from datetime import datetime, timedelta

# Manually set the start date to the day after the last successful fetch
last_successful_date = datetime(2017, 1, 31)  # This is the last date you know was completed
start_date = last_successful_date + timedelta(days=1)

# %%
import requests
import time

def fetch_articles(api_key, start_date, end_date):
    url = "https://api.marketaux.com/v1/news/all?symbols=TSLA&filter_entities=true&language=en&api_token=iy6rRX4oxFrouZocXr8JNpOzaxZLk3UvMfoMGxYs"
    headers = {"x-api-key": api_key}
    params = {
        "tickers": "TSLA",
        "filter_entities": "true",
        "language": "en",
        "from": start_date.strftime('%Y-%m-%d'),
        "to": end_date.strftime('%Y-%m-%d'),
        "page": 1
    }
    articles = []

    while True:
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()['data']
            articles.extend(data)
            if len(data) < 3:
                break
            params['page'] += 1
        else:
            print(f"Failed to fetch data: {response.text}")
            time.sleep(60)  # Wait a minute before retrying
            continue  # Optionally retry the same date range

        if params['page'] > 100:  # Adjust based on your daily limit
            break
        
        time.sleep(10)  # Sleep to avoid hitting the rate limit

    return articles

def fetch_data_from_date(api_key, start_date):
    current_date = datetime.now()
    while start_date <= current_date:
        end_date = start_date + timedelta(days=30)
        if end_date > current_date:
            end_date = current_date

        print(f"Fetching from {start_date.date()} to {end_date.date()}")
        articles = fetch_articles(api_key, start_date, end_date)
        
        # Assuming you have a function to save articles
        save_articles_to_json(articles)  # Save articles after each successful fetch

        start_date += timedelta(days=31)  # Move to the next month
        if len(articles) == 0:
            break  # Break the loop if no articles are returned

# Example usage
api_key = "iy6rRX4oxFrouZocXr8JNpOzaxZLk3UvMfoMGxYs"
fetch_data_from_date(api_key, start_date)
# Out:
# Fetching from 2017-02-01 to 2017-03-03
# Failed to fetch data: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# Failed to fetch data: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# Failed to fetch data: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# Failed to fetch data: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# Failed to fetch data: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# Failed to fetch data: {"error":{"code":"usage_limit_reached","message":"The usage limit for this account has been reached."}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb Cell 11 line 5
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=53'>54</a> # Example usage
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=54'>55</a> api_key = "iy6rRX4oxFrouZocXr8JNpOzaxZLk3UvMfoMGxYs"
# ---> <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=55'>56</a> fetch_data_from_date(api_key, start_date)
#
# /Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb Cell 11 line 4
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=41'>42</a>     end_date = current_date
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=43'>44</a> print(f"Fetching from {start_date.date()} to {end_date.date()}")
# ---> <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=44'>45</a> articles = fetch_articles(api_key, start_date, end_date)
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=46'>47</a> # Assuming you have a function to save articles
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=47'>48</a> save_articles_to_json(articles)  # Save articles after each successful fetch
#
# /Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb Cell 11 line 2
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=24'>25</a> else:
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a>     print(f"Failed to fetch data: {response.text}")
# ---> <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=26'>27</a>     time.sleep(60)  # Wait a minute before retrying
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a>     continue  # Optionally retry the same date range
#      <a href='vscode-notebook-cell:/Users/manos/Documents/BDS/MLops_mod/news_experimenting1.ipynb#X15sZmlsZQ%3D%3D?line=29'>30</a> if params['page'] > 100:  # Adjust based on your daily limit
#
# KeyboardInterrupt:

# %%
def save_articles_to_json(articles):
    with open('tesla_articles.json', 'a') as file:
        json.dump(articles, file)
